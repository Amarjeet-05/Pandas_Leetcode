# %%
import pandas as pd

# %%
data = [[1, 100]]
employee = pd.DataFrame(data, columns=['Id', 'Salary']).astype({'Id':'Int64', 'Salary':'Int64'})

# %%
employee
# Out:
#    Id  Salary
# 0   1     100

# %%
n = -1
if n <= 0:
    df = pd.DataFrame({f"getNthHighestSalary({n})" : [None]})

df
# if value of n is less then or equal to 0 so it gives none and end here
# in leetcode directly return this statement so after that no code will execute.
# Out:
#   getNthHighestSalary(-1)
# 0                    None

# %%
df = employee.drop_duplicates(subset='Salary', keep='first')

# %%
df = df['Salary'].nlargest(n).reset_index(drop=True)

# %%
df = pd.DataFrame(df)

# %%
if (len(df) < n)  :
    af = pd.DataFrame({f"getNthHighestSalary({n})" : [None]})
else:
    af = pd.DataFrame({f"getNthHighestSalary({n})" : df.iloc[n-1]})
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 4
#       2     af = pd.DataFrame({f"getNthHighestSalary({n})" : [None]})
#       3 else:
# ----> 4     af = pd.DataFrame({f"getNthHighestSalary({n})" : df.iloc[n-1]})
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/indexing.py:1192, in _LocationIndexer.__getitem__(self, key)
#    1190 maybe_callable = com.apply_if_callable(key, self.obj)
#    1191 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1192 return self._getitem_axis(maybe_callable, axis=axis)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/indexing.py:1753, in _iLocIndexer._getitem_axis(self, key, axis)
#    1750     raise TypeError("Cannot index by location index with a non-integer key")
#    1752 # validate the location
# -> 1753 self._validate_integer(key, axis)
# ...

# %%
af.reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 af.reset_index(drop=True)
#
# NameError: name 'af' is not defined
