# %%
import pandas as pd

# %%
data = [['A', 'Math'], ['B', 'English'], ['C', 'Math'], ['D', 'Biology'], ['E', 'Math'], ['F', 'Computer'], ['G', 'Math'], ['H', 'Math'], ['I', 'Math']]
courses = pd.DataFrame(data, columns=['student', 'class']).astype({'student':'object', 'class':'object'})

# %%
courses
# Out:
#   student     class
# 0       A      Math
# 1       B   English
# 2       C      Math
# 3       D   Biology
# 4       E      Math
# 5       F  Computer
# 6       G      Math
# 7       H      Math
# 8       I      Math

# %%
df = courses['class'].value_counts().reset_index()

# %%
df
# Out:
#       class  count
# 0      Math      6
# 1   English      1
# 2   Biology      1
# 3  Computer      1

# %%
 df = df[df['count'] >= 5][['class']]

# %%
df
# Out:
#   class
# 0  Math

# %%
# we can also do with groupby function

# %%
df2 = courses.groupby('class').count().reset_index()

# %%
df2 = df2[df2['student'] > 4][['class']]

# %%
df2
# Out:
#   class
# 3  Math
