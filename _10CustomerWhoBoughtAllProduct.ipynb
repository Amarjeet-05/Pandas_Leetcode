# %%
import pandas as pd

# %%
data = [[1, 5], [2, 6], [3, 5], [3, 6], [1, 6], [1,6]]
customer = pd.DataFrame(data, columns=['customer_id', 'product_key']).astype({'customer_id':'Int64', 'product_key':'Int64'})
data = [[5], [6]]
product = pd.DataFrame(data, columns=['product_key']).astype({'product_key':'Int64'})

# %%
customer
# Out:
#    customer_id  product_key
# 0            1            5
# 1            2            6
# 2            3            5
# 3            3            6
# 4            1            6
# 5            1            6

# %%
product
# Out:
#    product_key
# 0            5
# 1            6

# %%
df = pd.merge(customer, product, on='product_key')

# %%
df = df.drop_duplicates()

# %%
total_pro = product['product_key'].count()

# %%
df2 = df.groupby("customer_id")[['product_key']].count()

# %%
df
# Out:
#    customer_id  product_key
# 0            1            5
# 1            2            6
# 2            3            5
# 3            3            6
# 4            1            6

# %%
df2 = df2.reset_index()

# %%
af = pd.merge(df, df2, on='customer_id')

# %%
af
# Out:
#    customer_id  product_key_x  product_key_y
# 0            1              5              2
# 1            2              6              1
# 2            3              5              2
# 3            3              6              2
# 4            1              6              2

# %%
af[af['product_key_y'] == total_pro][['customer_id']].drop_duplicates()
# Out:
#    customer_id  product_key_y
# 0            1              2
# 2            3              2
