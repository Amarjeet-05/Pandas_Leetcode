# %%
import pandas as pd

# %%
data = [[1, 1], [2, 2], [3, 3], [4, 3], [5,3], [6,3]]
orders = pd.DataFrame(data, columns=['order_number', 'customer_number']).astype({'order_number':'Int64', 'customer_number':'Int64'})

# %%
orders
# Out:
#    order_number  customer_number
# 0             1                1
# 1             2                2
# 2             3                3
# 3             4                3
# 4             5                3
# 5             6                3

# %%
orders = orders['customer_number'].value_counts().reset_index()

# %%
orders
# Out:
#    customer_number  count
# 0                3      4
# 1                1      1
# 2                2      1

# %%
type(orders)
# Out:
# pandas.core.frame.DataFrame

# %%
orders.drop('count', axis=1, inplace=True)

# %%
orders
# Out:
#    customer_number
# 0                3
# 1                1
# 2                2
