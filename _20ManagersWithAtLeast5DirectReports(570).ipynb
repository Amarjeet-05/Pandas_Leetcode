# %%
import pandas as pd

# %%
data = [[101, 'John', 'A', None], [102, 'Dan', 'A', 101], [103, 'James', 'A', 101], [104, 'Amy', 'A', 101], [105, 'Anne', 'A', 101], [106, 'Ron', 'B', 101]]
employee = pd.DataFrame(data, columns=['id', 'name', 'department', 'managerId']).astype({'id':'Int64', 'name':'object', 'department':'object', 'managerId':'Int64'})

# %%
employee
# Out:
#     id   name department  managerId
# 0  101   John          A       <NA>
# 1  102    Dan          A        101
# 2  103  James          A        101
# 3  104    Amy          A        101
# 4  105   Anne          A        101
# 5  106    Ron          B        101

# %%
df = employee.groupby('managerId')[['department']].count().reset_index()

# %%
df
# Out:
#    managerId  department
# 0        101           5

# %%
df = df[df["department"] >= 5]

# %%
df = employee.merge(df, left_on="id", right_on="managerId")

# %%
df[['name']]
# Out:
#    name
# 0  John
