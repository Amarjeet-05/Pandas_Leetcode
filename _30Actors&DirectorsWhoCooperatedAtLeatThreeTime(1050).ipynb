# %%
import pandas as pd

# %%
data = [[1, 1, 0], [1, 1, 1], [1, 1, 2], [1, 2, 3], [1, 2, 4], [2, 1, 5], [2, 1, 6]]
actor_director = pd.DataFrame(data, columns=['actor_id', 'director_id', 'timestamp']).astype({'actor_id':'int64', 'director_id':'int64', 'timestamp':'int64'})

# %%
actor_director
# Out:
#    actor_id  director_id  timestamp
# 0         1            1          0
# 1         1            1          1
# 2         1            1          2
# 3         1            2          3
# 4         1            2          4
# 5         2            1          5
# 6         2            1          6

# %%
a = actor_director.groupby(['actor_id', 'director_id']).count().reset_index()

# %%
a
# Out:
#    actor_id  director_id  timestamp
# 0         1            1          3
# 1         1            2          2
# 2         2            1          2

# %%
a[a['timestamp'] >= 3][['actor_id', 'director_id']]
# Out:
#    actor_id  director_id
# 0         1            1
